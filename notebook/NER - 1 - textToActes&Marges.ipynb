# %%
from os.path import dirname, join
from os import listdir, getcwd

import pickle
import pandas as pd 
import sys
import pickle as pkl

PATH_REPO = getcwd()

PATH_DATA = join(PATH_REPO, 'data', '20230721_transcriptions')
PATH_LINES = join(PATH_DATA, 'lines')
PATH_XML = join(PATH_DATA, 'XML')
PATH_OCRized = join(PATH_DATA, 'OCRized')
PATH_PAGES = join(PATH_DATA, 'pages')
PATH_UTILS = join(PATH_REPO, 'utils')

sys.path.append(PATH_UTILS)

from parsing_lines import *
from xml.dom import minidom

# %%
def get_marges_and_corps(PATH_OCRized, th=25):

    texts = [x for x in listdir(PATH_OCRized) if '.txt' in x]
    texts.sort()
    lengths = [len([x[:-1] for x in open(join(PATH_OCRized, text), 'r').readlines()]) for text in texts]
    
    marges = [x[:-1] for text, length in zip(texts, lengths) if length <=th
         for x in open(join(PATH_OCRized, text), 'r').readlines()]
    corps = [x[:-1] for text, length in zip(texts, lengths) if length >th
             for x in open(join(PATH_OCRized, text), 'r').readlines()]
    
    photo_marges = [text.split('_column')[0] for text, length in zip(texts, lengths) if length <=th
     for x in open(join(PATH_OCRized, text), 'r').readlines()]
    
    photo_corps = [text.split('_column')[0] for text, length in zip(texts, lengths) if length >th
         for x in open(join(PATH_OCRized, text), 'r').readlines()]
    
    return marges, corps, photo_marges, photo_corps

# %%
for commune in communes[-1:]:
    years = [x for x in listdir(join(PATH_REPO, 'data', '20230721_transcriptions', commune)) if '.' not in x]
    for year in years[-1:]:
        PATH_DATA = join(PATH_REPO, 'data', '20230721_transcriptions', commune, year)
        PATH_LINES = join(PATH_DATA, 'lines')
        PATH_XML = join(PATH_DATA, 'XML')
        PATH_OCRized = join(PATH_DATA, 'OCRized')
        PATH_PAGES = join(PATH_DATA, 'pages')

        marges, corps, photo_marges, photo_corps = get_marges_and_corps(PATH_OCRized, th=30)

# %%
from Levenshtein import ratio
from collections import Counter

def duplicated_from_levenshtein(marge):
    """
    Objective: with the marge content find out words that are most likely related to the owrd list
    
    Inputs:
        - marge, str: the marge text
    Outputs:
        - duplicated, dict: the dictionary of words that should probably be one of the word list
    """
    
    words_list = ['naissance', 'reconnaissance', 'mariage',
                    'décès','présentation']

    words = [x.lower() for marge in marges for x in marge.split()]
    words_count = Counter(words)

    words_th = {'naissance':0.8, 
                'reconnaissance':0.8, 
                'mariage':0.85, 
                'décès': 0.7, 
                'présentation':0.85}

    duplicated = {word: [] for word in words_list}

    duplicated['décès'].append('veces')
    duplicated['décès'].append('décet')
    duplicated['décès'].append('decel')
    duplicated['décès'].append('Décéd')
    duplicated['décès'].append('Décil')
    duplicated['décès'].append('Dècès')
    duplicated['naissance'].append('nousSANCE')
    duplicated['naissance'].append('noussance')
    duplicated['naissance'].append('naissane')
    duplicated['reconnaissance'].append('Lecon NaISSANCE')
    duplicated['reconnaissance'].append('reconaissance')
    duplicated['reconnaissance'].append('Remaissance')

    for word in words_list:
        for c_word in np.unique(words):
            r = ratio(word, c_word)
            if r > words_th.get(word) and r < 1:
                duplicated[word].append(c_word)
                
    return duplicated

import re

def modify_with_levenshtein(marges, duplicated):
    """
    Objective: replace the words in marge that are most likely related to words into duplicated dict
    
    Inputs:
        - marges, list: the list of raw texts
        - duplicated, dict: dictionnary with fixed vocabulary and in values the words it could have written as
    Outputs:
        - marges, list: the list of cleaned texts
    """
    for word, duplicateds in duplicated.items():
        for _duplicated in duplicateds:
            _duplicated = _duplicated.replace('(', '\(').replace(')', '\)')
            for i, marge in enumerate(marges):
                marge = re.sub(r'(?:{}) '.format(_duplicated), 
                               word.capitalize(), marge, flags=re.I)
                marges[i] = marge
                
    return marges

def split_with_acte(marges):
    """
    Objective: split all marges to get for each element one acte only
    
    Inputs:
        - marges, list: the list of texts
    Outputs:
        - actes, list: list of texts where one item is one acte
        - regex, str: the regex to improve consolidation afterwords
    """
    actes_words = ['D[ée]c[èe]s', 'Naissance\s*(?:et|)\s*reco(?:|n)naissance',
                   'Recon(?:n|)aissance','Mariage', 'Pr[ée]sentation', 'Naissance']

    regex ='(?:N°\s*(?:{})|(?:N°|N|)\s*(?:\d+|L|S|)\s*(?:{}))'.format(
            '|'.join(actes_words[:4]),
                 '|'.join(actes_words))

    actes = re.split(r'({})'.format(regex), ' '.join(marges).replace('n°', 'N°'), flags=re.I)

    return actes, regex

def get_photos_by_actes(actes, marges, photo_marges):
    """
    Objective: get the related photos to each actes
    
    Inputs:
        - actes, list: list of texts where one item is one acte
        - marges, list: the list of texts
        - photos_marges, list: the list of photos associated
    Outputs:
        - photo_marges_actes, list: final list of the photos
    """

    i = 0
    j = 0
    k = 1
    photo_marges_actes = []
    merged_texts = []
    initial_text = ''
    
    while j < len(actes) and i < len(marges):
        text = actes[j]
        merged_text = (initial_text + ' ' + marges[i].replace('n°', 'N°').strip()).strip()

        while len(merged_text.strip()) < len(text.strip()) and i+k < len(marges) - 1:
            merged_text += ' ' + marges[i+k].replace('n°', 'N°').strip()
            k += 1

        initial_text = merged_text.strip()[len(text.strip()):]
        merged_text = merged_text.strip()[:len(text.strip())]

        photo_marges_actes.append(np.unique(photo_marges[i:i+k])[0])
        merged_texts.append(merged_text)

        i += k
        k = 1
        j += 1
    
    return photo_marges_actes


def consolidate_actes(actes, photo_marges_actes, regex):
    """
    Objective: from the actes and regex get the final actes, with one item is one acte
    
    Inputs:
        - actes, list: list of texts
        - regex, str: the regexes to help divide texts
    Outputs:
        - final_actes, list: the list of final actes
    """
    final_actes, final_photos = [], []

    final_acte = ''
    photo = None
    for acte, photo in zip(actes, photo_marges_actes):
        matches = re.findall(regex, acte, flags=re.I)
        if len(matches) > 0:
            if len(final_acte.strip()) > 0:
                final_actes.append(final_acte)
                final_photos.append(photo)
            final_acte = acte.strip()
        else:
            final_acte += ' ' + acte.strip()
            
    final_actes.append(final_acte.strip())
    final_photos.append(photo)
    
    return final_actes, final_photos

def get_sexe(acte, nom, type_acte):
    """
    Objective: get the sex of the acte depending on the name and type acte
    
    Inputs:
        - acte, str: the act text
        - nom, str: the name of the person in the act
        - type_act, str: the type of act
    Outputs:
        - sexe, str: 'M', 'F' or None
    """
    sexe = ''
    if nom != '':
        s = acte.split(nom)[0]
        if any(y in s.lower() for y in ['sr', 'sieur']):
            sexe = 'M'
        if any(y in acte for y in ['delle', 'dlle', 'demoiselle']):
            sexe = 'F'
        
    if any(y in acte for y in ['fils d', 'fils lé', 'fils n', 'naturel ']):
        sexe = 'M'
    if any(y in acte for y in ['fille d', 'fille lé', 'fille n', 'naturelle']):
        sexe = 'F'
        
    if type_acte == 'Présentation' and 'sexe' in acte.lower():
        if 'sexe masculin' in acte.lower():
            sexe = 'M'
        if 'sexe féminin' in acte.lower():
            sexe = 'F'
    return sexe

def get_nom(acte):
    """
    Objective: rfom the acte and thype of acte get the name
    
    Inputs:
        - acte, str: the act text
        - type_acte, str: the type of act
    Outputs:
        - nom, str: the name of the person mentioned in the act
    """
    acte = acte.strip()
    acte = re.sub(r'^\d+', '', acte)
    nom = re.sub(r'(?:Présentation|Décès|Reco(?:n|)naissance|Mariage|Naissance)', '', acte, flags=re.I).strip()
    nom = re.sub(r'^d[eu] ', '', nom, flags=re.I).strip()
    words_to_delete = ['enfant', 'l[ée]gitime', 'reconnu']
    nom = re.sub('(?:{})'.format('|'.join(words_to_delete)), '', nom).replace('  ', ' ').strip()
    nom = re.sub("(?:l'|)archiviste(.*?)$", '', nom).strip()
    nom = re.sub("\w+ mot(s)* ray[ée](s)* nul(s)*(.*?)$", '', nom).strip()
    nom = re.sub("(?:reconnu|D[eé]clar[eé]|ce renvoi|l[ée]gitime|lequel|sur|à|DÉCÉdÉ|MARIé) (.*?)$", '', 
                 nom, flags=re.I).strip()
    nom = re.sub("le (?:un|premier|deux|trois|quatre|cinq|six|sept|huit|neuf|dix|onze|douze|treize|quatorze|seize|vingt|trente)(.*?)$",
                 "", nom, flags=re.I).strip()
    
    return nom

def consolidate_df(final_actes):
    """
    Objective: consolidate from all information the dataset of marges
    
    Inputs:
        - final_actes, list: list of one item is an act
    Outputs:
        - df, pd.DataFrame: the dataset as dataframe
    """
    df = pd.DataFrame(columns=['acte', 'type_acte', 'numéro', 'nom', 'sexe'])

    replaces = [('N°', ''), ('Entre', 'entre'), ('(', ''), (')', ''), ('Enfant', 'enfant'), ('L\'', 'l\''),
               ('Sexe', 'sexe'), ('Mas', 'mas'), ('Fém', 'fém'), ('Légitime', 'légitime'), ('Nous', 'nous'),
                ('Sieur', 'sieur'), ('Dlle', 'dlle'), ('Sr', 'sr'), ('Témo', 'témo'), ('Témi', 'témi'),
                ('Par ', 'par '), ('Marié', 'marié')]

    for k, acte in enumerate(final_actes):
        for rep in replaces:
            acte = acte.replace(rep[0], rep[1])
        acte = re.sub('reconaissance', 'Reconnaissance', acte, flags=re.I)
        type_acte = re.findall(r'Pr[ée]sentation|D[ée]c[èe]s|Naissance\s*(?:et|)\s*reco(?:|n)naissance|Reconnaissance|Mariage|Naissance', acte, flags=re.I)
        type_acte = type_acte[0].lower() if len(type_acte) > 0 else 'none'
        if re.search('d[ée]c[èe]s', type_acte):
            type_acte = 'décès'
        if re.search('pr[ée]sentation', type_acte):
            type_acte = 'présentation'
        if re.search('naissance\s*(?:et|)\s*reconnaissance', type_acte):
            type_acte = 'naissance'

        num = re.search(r'^\d+', acte.strip())
        num = num.group() if num else None

        nom = get_nom(acte.strip())

        sexe = get_sexe(acte, nom, type_acte)

        df.loc[k, ['acte', 'type_acte', 'numéro', 'nom', 'sexe']] = acte, type_acte, num, nom, sexe
    
    return df

# %%
communes = [x for x in listdir(join(PATH_REPO, 'data', '20230721_transcriptions'))
            if x[0] != '.' and 'xlsx' not in x and 'csv' not in x and '.gz' not in x]
communes
# Out:
# ['Vieux Habitants',
#  '8. Capesterre de MG',
#  '23. Saint Esprit',
#  '3. Basse Pointe',
#  'Saint Louis',
#  '1. Abymes',
#  '14. Lorrain',
#  "16. Morne à l'Eau",
#  '21. Rivière Salée',
#  '19. Prêcheur',
#  '20. Rivière Pilote',
#  '31. Trois Ilets',
#  'Sainte Rose',
#  'Sainte Anne',
#  '14. Grand Bourg de MG',
#  '1. Ajoupa Bouillon',
#  'Trois Rivière',
#  '17. Moule',
#  '27. Sainte Luce',
#  '20. Pointe à Pitre',
#  '4. Carbet',
#  '12. Gourbeyre',
#  '24. Saint Joseph',
#  'Pointe à pitre',
#  '15. Macouba',
#  '22. Robert',
#  '16. Marigot']

# %%
df = pd.DataFrame()

for commune in communes:
    years = [x for x in listdir(join(PATH_REPO, 'data', '20230721_transcriptions', commune)) if '.' not in x]
    for year in years:
        PATH_DATA = join(PATH_REPO, 'data', '20230721_transcriptions', commune, year)
        PATH_LINES = join(PATH_DATA, 'lines')
        PATH_XML = join(PATH_DATA, 'XML')
        PATH_OCRized = join(PATH_DATA, 'OCRized')
        PATH_PAGES = join(PATH_DATA, 'pages')

        marges, corps, photo_marges, photo_corps = get_marges_and_corps(PATH_OCRized, th=30)
        duplicated = duplicated_from_levenshtein(marges)
        marges = modify_with_levenshtein(marges, duplicated)
        actes, regex = split_with_acte(marges)
        photo_marges_actes = get_photos_by_actes(actes, marges, photo_marges)
        final_actes, final_photos = consolidate_actes(actes, photo_marges_actes, regex)
        _df = consolidate_df(final_actes)
        _df.loc[:, 'picture'] = final_photos
        _df.loc[:, 'commune'] = commune
        _df.loc[:, 'year'] = year
        df = pd.concat((df, _df)).copy()

df.reset_index(drop=True, inplace=True)

# %%
len(df)
# Out:
# 66943

# %%
df.groupby(['type_acte'], group_keys=True).agg({'acte': 'count'})
# Out:
#                  acte
# type_acte
# décès           23771
# mariage          6580
# naissance       31692
# none              177
# présentation     2045
# reconnaissance   2678

# %%
len(df)
# Out:
# 66943

# %%
df.groupby(['type_acte'], group_keys=True).agg({'acte': 'count'})
# Out:
#                  acte
# type_acte
# décès           23771
# mariage          6580
# naissance       31692
# none              177
# présentation     2045
# reconnaissance   2678

# %%
df.loc[:, 'nom'] = df.loc[:, 'acte'].apply(lambda x: get_nom(x))

# %%
df.loc[(df.loc[:, 'numéro'] == '179') &
       (df.loc[:, 'commune'] == '3. Basse Pointe'), :]
# Out:
#                                                     acte  type_acte numéro  \
# 8327                  179 Décès du sieur Saint Lucien Nº      décès    179
# 8588     179 Naissance de sieur Prêcheur François Narier  naissance    179
# 8812               179 Naissance la sieur Calin Janville  naissance    179
# 8997                  179 Décès de d'nicodil avrilleine       décès    179
# 9427   179 Naissance de la Dl Alton Domi- nique Marie...  naissance    179
# 9708   179 Décès d'un enfant mort-né 180 Décédé lieu ...      décès    179
# 9949     179 Naissance du sieur Guston Erem Bert Camille  naissance    179
# 10217  179 Naissance et reconnait nier Jean Théodore ...  naissance    179
#
#                                                      nom sexe  \
# 8327                               sieur Saint Lucien Nº
# 8588                      sieur Prêcheur François Narier
# 8812                             la sieur Calin Janville
# 8997                                d'nicodil avrilleine
# 9427   la Dl Alton Domi- nique Marie 15 B 25 &5 F. S ...
# 9708                                    d'un mort-né 180
# 9949                      sieur Guston Erem Bert Camille
# 10217                    et reconnait nier Jean Théodore
#
#                             picture          commune  year
# 8327         FRANOM21_1DPPC1255_154  3. Basse Pointe  1852
# 8588         FRANOM21_1DPPC1274_224  3. Basse Pointe  1896
# 8812         FRANOM21_1DPPC1255_237  3. Basse Pointe  1853
# 8997   DAFCAOM04_DPPCEC_850477_0055  3. Basse Pointe  1854
# 9427         FRANOM21_1DPPC1274_060  3. Basse Pointe  1894
# 9708         FRANOM21_1DPPC1273_232  3. Basse Pointe  1893
# 9949         FRANOM21_1DPPC1273_141  3. Basse Pointe  1892
# 10217        FRANOM21_1DPPC1274_139  3. Basse Pointe  1895

# %%
#~~~~~ as a split ?
df.loc[14547, 'acte']
# Out:
# "n NaISSANCE Joséphine Landre. Cultyloie et Sandre Lazarre Agénon par leur mère la demoiselle Lapalme Marie Noël Le 14 novembre 1892  et Treize mots rayés nuls l'Jean Ahouz Ile sart  Zueol"

# %%
df.loc[55873, 'acte']
# Out:
# '164 Décès de sieur Vallianne Gaësan Paul'

# %%
acte = ''
type_acte = re.findall(r'Pr[ée]sentation|D[ée]c[èe]s|Naissance\s*(?:et|)\s*reco(?:|n)naissance|Reconnaissance|Mariage|Naissance', acte, flags=re.I)

# %%
i = np.random.randint(0, len(df) - 50)
df.loc[i:i+50, :]
# Out:
#                                                     acte       type_acte  \
# 14506  n Naissance Est comparu dont la cécontre, dont...       naissance
# 14507  142 NAISSANCE Marie Antonine Justine fille nat...       naissance
# 14508  143 NAISSANCE Rancel Adrien fils légitime Le 9...       naissance
# 14509  144 NAISSANCE d° Lamaille Victor Joseph fils r...       naissance
# 14510  145 NAISSANCE Janissois Lambert Certullien fil...       naissance
# 14511  146 NAISSANCE Pierre Henri fils naturel Le 19 ...       naissance
# 14512  147 NAISSANCE Delrain Adélaïde Florence fille ...       naissance
# 14513   148 NAISSANCE Beoffroy Henry Edmand fils légi...       naissance
# 14514  141 NAISSANCE 16 Haugie Prembert Bernadin fils...       naissance
# 14515   150 NAISSANCE Bourgarelle Saint-Louis Zéphiri...       naissance
# 14516  131 ReconNAISSANCE Desirée par son père le sie...  reconnaissance
# 14517  132 Reconnaissance Valentine André Justine et ...  reconnaissance
# 14518  153 NAISSANCE Holin Louisia Sille légitime Le ...       naissance
# 14519  mariage xélébré à la la la mairie des Abymes l...         mariage
# 14520  naissance est constatrice dans Dont mention fa...       naissance
# 14521  153 NAISSANCE Filomin Denis fils reconnu Le 9 ...       naissance
# 14522  156 NAISSANCE do Félicienne Lucine Marie Franç...       naissance
# 14523   157 NAISSANCE Indor 6° Pierre Charles Camons ...       naissance
# 14524  158 NAISSANCE d° André Lubin Marie Laurence fi...       naissance
# 14525  139 NAISSANCE d° Mathilde Eugénie fille nature...       naissance
# 14526  160 NAISSANCE Aphonsine fille naturelle Le 14 ...       naissance
# 14527  167 NAISSANCE Clise Marie Lucia Martinienne Si...       naissance
# 14528  162 NAISSANCE Melson Alexandrine fille légitim...       naissance
# 14529  165 NAISSANCE Loulou Lucie Adélaïde fille reco...       naissance
# 14530                                  1882 NAISSANCE d°       naissance
# 14531  NAISSANCE 42 f Aujourd'hui mil huit cent quatr...       naissance
# 14532  présentation faites en présence des sieurs et ...    présentation
# 14533  naissance après qu'il leur en a été donné lect...       naissance
# 14534  présentation faites en présence des sieurs et ...    présentation
# 14535  naissance après qu'il leur en a été donné lect...       naissance
# 14536  présentation hier en présence des sieurs, fils...    présentation
# 14537  naissance après qu'il leur en a été donné lect...       naissance
# 14538  NAISSANCE NoZas Evariste fils reconnu Le 2° Oc...       naissance
# 14539  167 Reconnaissance f. d° Robin Pernand Augusti...  reconnaissance
# 14540   168 NAISSANCE Comile Auguste Marcifse fils lé...       naissance
# 14541  169 NAISSANCE Bourquignon Faumence. Beatrix fi...       naissance
# 14542  170 NAISSANCE Charles Renellier Le 28 Octobre ...       naissance
# 14543  171 NAISSANCE Dousardo Marie CouSine fille lég...       naissance
# 14544  172 NAISSANCE Laure Marie Elisabeth a déclaré ...       naissance
# 14545  175 NAISSANCE de Séccarius Adélaïde fille reco...       naissance
# 14546  n NaISSANCE Auguste Samphile à déclaré vouloir...       naissance
# 14547  n NaISSANCE Joséphine Landre. Cultyloie et San...       naissance
# 14548  176 NAISSANCE de Anastasie fille naturelle Le ...       naissance
# 14549  NAISSANCE Emile Prosper fils naturel Le 7 nove...       naissance
# 14550  378 NAISSANCE do Berthilde fille naturelle Le ...       naissance
# 14551  179 NAISSANCE de Marie fille naturelle Le 8 No...       naissance
# 14552                                    1882 NAISSANCE        naissance
# 14553   NAISSANCE Brièle Aujourd'hui mil huit cent qu...       naissance
# 14554  présentation faites en présence des sieurs et ...    présentation
# 14555  naissance après qu'il leur en a été donné lect...       naissance
# 14556  présentation faites en présence des sieurs et ...    présentation
#
#       numéro                                                nom sexe  \
# 14506   None  n Est comparu dont la cécontre, dont mention f...
# 14507    142  Marie Antonine Justine fille naturelle Le 7 Se...    F
# 14508    143             Rancel Adrien fils Le 9 Septembre 1892    M
# 14509    144  d° Lamaille Victor Joseph fils Le 17 septembre...
# 14510    145  Janissois Lambert Certullien fils Le 18 septem...
# 14511    146     Pierre Henri fils naturel Le 19 Septembre 1852    M
# 14512    147  Delrain Adélaïde Florence fille e Le 24 Septem...    F
# 14513    148    Beoffroy Henry Edmand fils Le 29 septembre 1882    M
# 14514    141  16 Haugie Prembert Bernadin fils Le 30 Septemb...    M
# 14515    150  Bourgarelle Saint-Louis Zéphirin fils Le 4 Oct...
# 14516    131  Desirée par son père le sieur Roquine Aurèle L...
# 14517    132  Valentine André Justine et Marie Madeleine par...
# 14518    153    Holin Louisia Sille Le 7 Octobre 1882 l'an leur
# 14519   None                                            xélébré
# 14520   None  est constatrice dans Dont mention faite par no...
# 14521    153     Filomin Denis fils Le 9 Octobre 1892 ensciliés
# 14522    156  do Félicienne Lucine Marie Françuile fille Le ...    F
# 14523    157  Indor 6° Pierre Charles Camons fils Le 12 Octo...
# 14524    158  d° André Lubin Marie Laurence fille Le 12 Octo...    F
# 14525    139  d° Mathilde Eugénie fille naturelle Le 12 Octo...    F
# 14526    160  Aphonsine fille naturelle Le 14 Octobre 1892 m...    F
# 14527    167  Clise Marie Lucia Martinienne Sille Le 16 Octo...
# 14528    162        Melson Alexandrine fille Le 17 Octobre 1852    F
# 14529    165        Loulou Lucie Adélaïde fille e Le 18 Octobre
# 14530   1882                                                 d°
# 14531   None    42 f Aujourd'hui mil huit cent quatre-vingt-dou
# 14532   None  faites en présence des sieurs et signé avec no...
# 14533   None  après qu'il leur en a été donné lecture --- Au...
# 14534   None  faites en présence des sieurs et f signé avec ...
# 14535   None  après qu'il leur en a été donné lecture Ajourd...    M
# 14536   None  hier en présence des sieurs, fils commune Le S...
# 14537   None         après qu'il leur en a été donné lecture 1°
# 14538   None             NoZas Evariste fils Le 2° Octobre 1892
# 14539    167  f. d° Robin Pernand Augustin Robin Marie Camil...    F
# 14540    168   Comile Auguste Marcifse fils Le 28 Octobbre 1892    M
# 14541    169  Bourquignon Faumence. Beatrix fille e Le 28 Oc...
# 14542    170  Charles Renellier Le 28 Octobre 1892 x et le s...
# 14543    171  Dousardo Marie CouSine fille Le 1er Novembre 1892    F
# 14544    172                            Laure Marie Elisabeth a    F
# 14545    175  Séccarius Adélaïde fille é Le 4 novembre 1882 ...
# 14546   None                                 n Auguste Samphile    M
# 14547   None  n Joséphine Landre. Cultyloie et Sandre Lazarr...    F
# 14548    176  Anastasie fille naturelle Le 7 Novembre 1892 d...    F
# 14549   None  Emile Prosper fils naturel Le 7 novembre 1822 ...    M
# 14550    378    do Berthilde fille naturelle Le 7 Novembre 1892    F
# 14551    179                Marie fille naturelle Le 8 Novembre    F
# 14552   1882
# 14553   None  Brièle Aujourd'hui mil huit cent quatre-vingt-...
# 14554   None  faites en présence des sieurs et signé avec no...
# 14555   None  après qu'il leur en a été donné lecture 16 Auj...
# 14556   None  faites en présence des sieurs et signé avec no...
#
#                       picture    commune  year
# 14506  FRANOM21_1DPPC0039_173  1. Abymes  1892
# 14507  FRANOM21_1DPPC0039_173  1. Abymes  1892
# 14508  FRANOM21_1DPPC0039_173  1. Abymes  1892
# 14509  FRANOM21_1DPPC0039_173  1. Abymes  1892
# 14510  FRANOM21_1DPPC0039_174  1. Abymes  1892
# 14511  FRANOM21_1DPPC0039_174  1. Abymes  1892
# 14512  FRANOM21_1DPPC0039_174  1. Abymes  1892
# 14513  FRANOM21_1DPPC0039_174  1. Abymes  1892
# 14514  FRANOM21_1DPPC0039_175  1. Abymes  1892
# 14515  FRANOM21_1DPPC0039_175  1. Abymes  1892
# 14516  FRANOM21_1DPPC0039_175  1. Abymes  1892
# 14517  FRANOM21_1DPPC0039_175  1. Abymes  1892
# 14518  FRANOM21_1DPPC0039_176  1. Abymes  1892
# 14519  FRANOM21_1DPPC0039_176  1. Abymes  1892
# 14520  FRANOM21_1DPPC0039_176  1. Abymes  1892
# 14521  FRANOM21_1DPPC0039_176  1. Abymes  1892
# 14522  FRANOM21_1DPPC0039_176  1. Abymes  1892
# 14523  FRANOM21_1DPPC0039_177  1. Abymes  1892
# 14524  FRANOM21_1DPPC0039_177  1. Abymes  1892
# 14525  FRANOM21_1DPPC0039_177  1. Abymes  1892
# 14526  FRANOM21_1DPPC0039_177  1. Abymes  1892
# 14527  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14528  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14529  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14530  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14531  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14532  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14533  FRANOM21_1DPPC0039_178  1. Abymes  1892
# 14534  FRANOM21_1DPPC0039_179  1. Abymes  1892
# 14535  FRANOM21_1DPPC0039_179  1. Abymes  1892
# 14536  FRANOM21_1DPPC0039_179  1. Abymes  1892
# 14537  FRANOM21_1DPPC0039_180  1. Abymes  1892
# 14538  FRANOM21_1DPPC0039_180  1. Abymes  1892
# 14539  FRANOM21_1DPPC0039_180  1. Abymes  1892
# 14540  FRANOM21_1DPPC0039_180  1. Abymes  1892
# 14541  FRANOM21_1DPPC0039_181  1. Abymes  1892
# 14542  FRANOM21_1DPPC0039_181  1. Abymes  1892
# 14543  FRANOM21_1DPPC0039_181  1. Abymes  1892
# 14544  FRANOM21_1DPPC0039_181  1. Abymes  1892
# 14545  FRANOM21_1DPPC0039_182  1. Abymes  1892
# 14546  FRANOM21_1DPPC0039_182  1. Abymes  1892
# 14547  FRANOM21_1DPPC0039_182  1. Abymes  1892
# 14548  FRANOM21_1DPPC0039_182  1. Abymes  1892
# 14549  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14550  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14551  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14552  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14553  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14554  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14555  FRANOM21_1DPPC0039_183  1. Abymes  1892
# 14556  FRANOM21_1DPPC0039_185  1. Abymes  1892

# %%
df.to_csv(join(PATH_REPO, 'data', '20230817_transcriptions', 'marges.csv'), index=False)

# %% [markdown]
# # Corps du texte

# %% [markdown]
# ## Split the text in actes
#
# Needs to improve after the next training.

# %%
def split_acte_in_corps(marges):
    """
    Objective. split the texts into actes
    """
    actes_words = ['Décès', 'Naissance\s*(?:et|)\s*reco(?:n|)naissance',
                   'Recon(?:n|)aissance','Mariage', 'Présentation', 'Naissance']

    regex = '(?:N°\s*(?:{})|(?:N°|N|)\s*(?:\d+\s*|L|S|)\s*(?:{}))'.format('|'.join(actes_words[:3]),
                 '|'.join(actes_words))

    actes = re.split(r'({})'.format(regex), ' '.join(marges).replace('n°', 'N°'), flags=re.I)

    return actes, regex

# %%
def duplicated_word_corps_from_levenshtein(corps):
    """
    Objective: get a dictionnary of words that should be replaced by the most common in our context (words_list)
    
    Inputs:
        - corps, list: list of texts
    Outputs:
        - ducplicated, dict: the dictionnary of words to replace misspelled ones
    """
    words_list = ["aujourd'hui", 'par-devant', 'naissance', 'décès', 'mariage']

    words = [x.lower() for marge in corps for x in marge.split()]
    words_count = Counter(words)

    words_th = {
                "aujourd'hui":0.9,
                "par-devant":0.8,
                'naissance':0.8, 
                'mariage':0.9, 
                'décès': 0.8
               }

    duplicated = {word: [] for word in words_list}
    
    for word in words_list:
        for c_word in np.unique(words):
            r = ratio(word, c_word)
            if r >= words_th.get(word) and r < 1:
                duplicated[word].append(c_word)
                
    return duplicated

def modify_with_levenshtein(marges, duplicated):
    """
    Objective: replace words in the text (marges) that are most likely present in the duplicated dict
    
    Inputs:
        - marges, list: list of texts
        - duplicated, dict: the words to focus on that may be a bit changed
    Outputs.
        - marges, list: list of cleaned texts
    """
    for word, duplicateds in duplicated.items():
        for _duplicated in duplicateds:
            _duplicated = _duplicated.replace('(', '\(').replace(')', '\)')
            for i, marge in enumerate(marges):
                marge = re.sub(r'\b(?:{}|{}|{})\b'.format(_duplicated, _duplicated.capitalize(), _duplicated.upper()), 
                               word.capitalize(), marge)
                marges[i] = marge
                
    return marges

def split_corps_in_actes(corps):
    """
    Objective: from the corps, try to have one item one acte
    
    Inputs:
        - corps, list: list of texts
    Outputs:
        - actes, list. the list of actes one items is an act
    """
    actes = []

    acte = ''
    for text in corps:
        if re.search("^(?:aujourd'hui|l'an )", text.lower()):
            if len(acte) < 500 and len(actes) > 0:
                actes[-1] += ' ' + acte
            else:
                actes.append(acte)
            acte = text
        else:
            acte += ' ' + text
            
    return actes

# %%
df = pd.DataFrame()

for commune in communes:
    years = [x for x in listdir(join(PATH_REPO, 'data', '20230721_transcriptions', commune)) if '.' not in x]
    for year in years:
        PATH_DATA = join(PATH_REPO, 'data', '20230721_transcriptions', commune, year)
        PATH_LINES = join(PATH_DATA, 'lines')
        PATH_XML = join(PATH_DATA, 'XML')
        PATH_OCRized = join(PATH_DATA, 'OCRized')
        PATH_PAGES = join(PATH_DATA, 'pages')

        marges, corps, photo_marges, photo_corps = get_marges_and_corps(PATH_OCRized, th=30)
        duplicated = duplicated_word_corps_from_levenshtein(corps)
        corps = modify_with_levenshtein(corps, duplicated)
        actes = split_corps_in_actes(corps)
        photo_corps_actes = get_photos_by_actes(actes, corps, photo_corps)
        if len(actes) < 1:
            continue
        _df = pd.DataFrame(actes, columns=['acte'])
        _df.loc[:, 'photo'] = photo_corps_actes
        _df.loc[:, 'commune'] = commune
        _df.loc[:, 'year'] = year
        df = pd.concat((df, _df)).copy()

df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                                     acte  \
# 0                                        Premier juillet
# 1      Aujourd'hui, Samedi Six Janvier mil huit cent ...
# 2      Aujourd'hui, Lundi huit Janvier mil huit cent ...
# 3      Aujourd'hui, Lundi huit Janvier mil huit cent ...
# 4      Aujourd'hui, Samedi treize Janvier mil huit ce...
# ...                                                  ...
# 76873  L'an mil huit cent quatre-vingt-quinze, le hui...
# 76874  L'an mil huit cent quatre vingt-quinze, le neu...
# 76875  L'an mil huit cent quatre vingt-quinze, le onz...
# 76876  L'an mil huit cent quatre vingt quinze, le sei...
# 76877  L'an mil huit cent quatre vingt quinze, le vin...
#
#                         photo          commune  year
# 0      FRANOM49_1DPPC0954_225  Vieux Habitants  1855
# 1      FRANOM49_1DPPC0954_225  Vieux Habitants  1855
# 2      FRANOM49_1DPPC0954_225  Vieux Habitants  1855
# 3      FRANOM49_1DPPC0954_226  Vieux Habitants  1855
# 4      FRANOM49_1DPPC0954_226  Vieux Habitants  1855
# ...                       ...              ...   ...
# 76873  FRANOM21_1DPPC1705_078      16. Marigot  1895
# 76874  FRANOM21_1DPPC1705_078      16. Marigot  1895
# 76875  FRANOM21_1DPPC1705_079      16. Marigot  1895
# 76876  FRANOM21_1DPPC1705_079      16. Marigot  1895
# 76877  FRANOM21_1DPPC1705_079      16. Marigot  1895
#
# [76878 rows x 4 columns]

# %%
for text in df.sample(10).acte.values:
    print(text)
    print('----')
# Out:
# L'an mil huit cent cinquante quatre et le premier du mois d'a¬ ind à huit heures du matin. Par-devant nous Frédéric sise en cide Latama le adjoint au Maire de Son d° d° Frêcheur arrondissement de Saint Pierre île Martinique aux présent les fonctions d'officier de l'Etat civil par délégation du Marin en date du premier Décembre dernier a comparu la demoiselle Collus Rose agée du dix neuf ans, fille naturelle de la demoiselle Collius Euphrasie âgée de quarante trois ans, toute deux cultivateurs domiciliés dans cette Commune. Lesquels nom de claré qu'il est né d'elle dans sa case Soir en Bourg de cette Commune, le Seize mars dernier à six heures du matin, un enfant du sexe masculin quelle nous présente et auquel elle déclare vouloir donner le prénom de Parul. Les dites déclaré que et présentation faites en présence des Sieurs Livorg Joseph, âgé de trente quatre ans et Gernet Romain agé de vingt trois ans, tous deux cultivateurs domiciliés dans cette Commune, voisins de la déclarante, témoins choisis et appelés par elle qui n'ont pu ainsi que cette dernière signer avec nous le présent acte, ne sachant par écrire après lecture faite Signique de la Commune
# ----
# L'an mil huit cent cinquante deux et le huitième Jour du mois d'avril, à huit heures du matin, par devant nous, Jude de Doyer, maire de la Commune de Sainte Rose canton du Lamentin, arrondissement de la Pointe aprètre, île Guadeloupe et, en Cette qualité, chargé de cette publications d'of ficier de l'état Civil, Sont comparus, en notre Maison Commune, le Sieur Mathieu Picard, âgé de trente huit ans, boul ger, et Pierre Navarre, âgé de trente sept ans, forgeron l'un et l'autre demeurant en Cette Commune. le squels nous ont déclaré que hier septième Jour de le présent mois d'avril à huit heures quarante Cinq minutes du Soir, et fer l'habitation la Bonne Mère, fille en la Susdite Commune de Sainte Rose, lieu de Son domicile, le Sieur Bertrand Ar tique, âgé de quarante trois ans, habitant non marie, né à Lande, département de la trente Garonne arrondissement de Saint Godine, et ilsu de parents inconnus est décédé, ainsi que nous nous en Sommes assuré, et les déclarants amis du décédé ont signé avec nous le présent acte après qu'il leur en a été fait lecture Mavarre Mathieu Le Maire, Meyerg N°143
# ----
# L'an mil huit cent cinquante-trois, et le neuf du mois de mai à trois heures d'domie de l'après midi, dentist nous Jean. François Rémy Le Sade, âgé de trente-trois ans, maire, officier de l'état civil de la commune du Lorrain Grand'anSe et Marigot arrondissement de Saint Pierre Ile Martinique est comparue la demoiselle Marie Françoise Causol, âgé de vingt-cinq ans, cultivatrice, domiciliée liée à la Grand'Anse, sur l'habitation des Sieurs Alfred de Montrose et Joûti, laquelle nous a déclaré que le trente un du mois de mars dernier, à quatre heures de l'après midi, il est né en Sa demeure sur l'habitation Sus désigné d'elle comparante, un enfant du sexe masculin qu'elle nous présente, et auquel elle déclare donner les prénoms de Saint-après, se reconnaissant pour être la mère de cet enfant. Les dites déclaration et présentation, faites en présence des Sieurs Hippolyte Vildoul âgé de vingt-cinq ans et Jean Louis Lina, âgé de vingt-deux ans, tous deux cultivateurs domiciliés à la Grand'anse sur l'habitation des dits Sieurs ASser de Montrose et suité, témoins choisis par la comparante; avons signé seul le présent acte de naissance, la mère et les témoins ayant déclaré ne savoir signer, de ce par nous requis après qu'il leur en a été donné lecture./. Rélude
# ----
# L'an mil huit cent quatre vingt treize, le sept février, à neuf heures du mois du matin-acte de naissance de l'anony Lucie, du sexe féminin, née en cette ville le deux février courant, à deux heures du matin, maison du sieur Celestin Nicolas rue de Nozières, où demeure le père du mariage du sieur Janamy (Saint Jean), âgé de trente six ans, restaurateur, avec la dame Bausset (Marguerite augustina) âgée de dix neuf ans, sans pro- -fession, tous deux domiciliés en cette ville. Constaté par Nous, Marie dieudonné adolphe Cicéron, premier adjoint au Maire de la Pointe à- Pitre, délégué aux fonctions d'officier de l'Etat-Civil, auquel l'en fant a été présentés sur la déclaration du père faite en présence des sieurs Fernand Lian, âgé de vingt huit ans, tailleur d'ha- -bits, et Sarnuel Bourdon, âgé de vingt cinq ans, employé de commerce, tous deux domiciliés en la même ville, les quels ont signé avec le père et Nous, après lecture; N° (Hippel Ranand) Jules-Sart Mmes N°52 P
# ----
# L'An mil huit cent quatre vingt quatorze, le quatre juin 894 Mai, à deux heures du soir, Acte de Naissancede Athénaïde Plavie Lilha, du sexe féminin, né en cette ville le dix Mai ville, rue de Nassau, où demeure la mère, fille de la demoiselle, et Agnès Charlerine Horasius, âgée de dix-neuf ans, sans profest sion, domicilié en cette ville. Constaté par nous, Justin Armand Omer Jeanne, chevalier de la légion d'honneur, Maire de la Pointe à Pitre, auquel l'enfant a été présenté. sur la né le Jration de la dame Coulno Raymond, veuve du sieur Charlery Horatius, âgée de quarante-quatre ans, sans profession, domici- liée en cette ville, qui a soissé à l'accouchement, faite en pré- sence des sieurs Louis Toussaint, âgé de vingt-cinq ans, coiffeurs, et Urbain Comer, âgé de vingt-un ans révolus, employé de commer et ce, tous deux, domiciliés en la même ville, lesquels ont signé avec nous, re la comparante de ce requise, ayant déclaré ne le savoir, après lecture Hospaint Ch Comce
# ----
# L'an mil huit cent quatre vingt-quinze et le trente mai, à sept heures du matin; Par-devant nous Louis, Emélius Méérol Hec mil, premier adjoint au maire de la Commune du Robert canton de la Trinité, arrondissement de Saint Pierre, île Mai sinique, délégué aux fonctions d'officier de l'état civil de la dite Commune par arrêté du maire en date du dix avril mil huit cent quatre vingt deux, A comparu la demoiselle Agathe Benjamin, âgée de vingt-cinq ans, cultivatrice, domiciliée en cette commune laquelle nous a déclaré que le premier mai courant, à deux heures du matin, elle est accouchée en sa demeure sise à la Bol taire s'un enfant du sexe masculin qu'elle nous présente et auquel elle donne le prénom de Séraphim, se reconnaissant pour être la mère de cet enfant, Les dites déclaration et présentation faites en présence des Sieurs Pierre Volosier, âgé de vingt-trois ans, et Pam- phile, Célamen, âgé de trente-quatre ans, cultivateur, domici- liés en cette Commune, témoins non parent de l'enfant et choisis par la déclarante; Et avons seul signé le présent acte, la mère de l'enfant et les témoins n'ayant su le faire, de ce requis lecture faite Méros f.
# ----
# L'an mil huit cent quatre vingt treize, le trente nécembre à huit heures du matin, Par-devant nous de Lachenotière, Octave Bernard adjoint au Maire de la com- maire du Prêcheur, arrondissement de Saint Pierre, île Martinique, délégué à l'Etat civil par arrêté du Maire en date du dix huit juillet mil huit cent quatre vingt-douze sont comparus les sieurs Carra, Romald, âgé de cinquante et un ans et Descailles Julien, âgé de vingt-six ans, tous deux propriétaire, domicilié au Prêcheur, voisins du défunt ci-à pis dénommé; lesquels nous ont déclaré que hier à midi, dans sa maison sise au bourg de cette commune est décédé ainsi que nous nous en sommes, assuré le sieur Jean Joseph Amour Jean Baptiste, âgé de cinquante sept ans, par huit taire, premier adjoint au Maire de la dite commune, ne et domicilié au Prêcheur, fils légitime de sieur Jean Joseph et de dame Raymond Christine Elizabeth, tous deux décédés et des dames époux de la dame Céreau Eugénie, âgée de trente sept ans, propriétaire, domicilié au Prêcheur, Les tous deux ont signé avec nous, lecture faite Ch. Carra J. Descailles B. de Lachevrotier
# ----
# Aujourd'hui treize du mois de décembre mil huit cent cinquante-quatre, à neuf heures du matin par-devant nous Sidny Demouille Maire et Officier de l'Etat civil de la commune de la Capesterre Marie Galante, sont comparus les Sieurs Anneuville Garçon âgé de vingt deux ans et Saint Ville Filoche âgé de trente quatre ans, tous deux cultivateurs domiciliés en cette commune, Section des Baliziers, hameau Grand Etang N° 16 et 5, amis des défunt ci après dénum nre, lesquels nous ont déclaré que le quinze de ce mois jourd'hier à Sept heures du Soir, le Sieur Jules Isaac âgé de quatorze ans Sans profession domicilié en cette commune, Section des Baliziers, hameau Côte N° s, né en cette île, fils naturel de la demoiselle Marie Isaac, couturière domiciliée en la dite commune section des Baliziers, hameau dite N°s est décédé en la demeure de sa mère sise au dit hameau Cato en cette déclaration et après nous être assuré dudit Décès nous avons dressé le présent Acte, qui a été signé sur les Registres par nous Seul après lecture donnée, les déclarants ayant répondu de ce requis ne Savoir écrire ni Signer. J demoiselle N° N°
# ----
# L'an mil huit cent quatre vingt-treize, le trois juin, à neuf heures du matin, par devant nous Zéphora Louis-Pélix Maire et officier de l'état civil de la commune de Saint-Joseph canton du Lamentin, arrondissement de Fort-de-France, Martini que, a comparu le sieur Clément Georges Timier, âgé de qua- faite-quatre ans, cultivateur, domicilié à Saint-Joseph, le quel nous a présenté une enfant du sexe féminin, née le premier mai dernier, à quatre heures du matin, en sa demeure, au quartier Fonds Gombi, sis dans cette commune, de lui déclarant, et de la dame Marie Haurilia, et Uéry, son épouse, âgée de trente-sept ans, cultivatrice, domiciliée avec lui et à laquelle enfant il a donné le prénom de et quès. Les dites déclaration et présentation faites en présence des sieurs Joseph Gaudar, âgé de trente-huit ans, chau dromier, Marc Laure, âgé de trente-deux ans, cultivateur, domi- ciliés à Saint-Joseph, témoins choisis par le comparant. Lecture faite du présent acte, nous l'avons seul signé; le père et les témoins ayant dit ne savoir le faire./. le prénom de l'Etat civil en a été présé aux elphe E.10108 de, Sofie,
# ----
# Aujourd'hui Vingt sept juin mil huit cent quatre-vingt-treize à quatre heures du l'après midi par-devant nous Landry Cessy, deuxième Adjoint au Maire, remplissant par délégation, les fonctions de Officier de l'état civil de la Commune du Moule, est comparu le Sieur Jean Pierre Sarole, agé de vingt sept ans, manoeuvre domicilié au Moule lequel nous a présenté un enfant du sexe féminin, née le dix neuf du Courant, à quatre heures et demie du matin, sur l'habi -tation Bonan, Située en cette Commune, section de la Baie du Nous-Onest, se reconnaissant pour être le père de cette enfant et l'avoir eue de la demoiselle Laure Saint Phor, agée de vingt cinq ans, servante, domici liée au Moule, et à laquelle, il a déclaré vouloir donner les prénoms de Eulalie Marguerite et lesdites déclaration et présentation faites en présence des sieurs Wulfrid Ibrahim, agé de trente huit ans et Augustin Carreau, agé de vingt quatre ans, tous deux charpentiers, domiciliés au Moule, non parents ni voisins de et a le second témoin seul signé avec nous le présent acte de naissance après qu'il leur en a été donné lecture, les comparant et premier témoin ayant déclaré ne le savoir, de ce interpellés Carron Augustin P de f 919
# ----

# %% [markdown]
# ## Preprocess acte

# %%
df.loc[:, 'acte_pp'] = df.loc[:, 'acte'].apply(lambda x: x.replace('- -', '').replace(' -', '').replace('- ', ''))
df.loc[:, 'acte_pp'] = df.loc[:, 'acte_pp'].apply(lambda x: re.sub('[sS]ieur(?:s|)(?: |-)[hH]abitan(?:t|)(?:s|)', 
                                                                   'Vieux Habitants', x))
df.loc[:, 'acte_pp'] = df.loc[:, 'acte_pp'].apply(lambda x: re.sub('Vieux-habitation', 
                                                                   'Vieux Habitants', x))

# %% [markdown]
# ## Extract key info:
#
# - Date du registre
# - Type évènement (mariage, décès, naissance, reconnaissance)
# - Lieu évènement si présent
# - Date évènement
#
#
# - Sujet(s): qui est le sujet de l'acte
#     * Nom
#     * Age
#     * Profession
#     * Lieu de naissance
#     * Résidence
#     * Genre
#
#
# - Père et/ou Mère:
#     * nom
#     * age
#     * profession
#     * lieu de naissance
#     * en vie ?
#     * résidence

# %% [markdown]
# ### Info registre
#
# **Date**

# %%
jours = ['un', 'deux', 'trois', 'quatre', 'cinq', 'six', 'sept',
         'huit', 'neuf', 'dix', 'onze', 'douze', 'treize', 
         'quatorze', 'quinze', 'seize', 'dix-sept', 'dix-huit', 
         'dix-neuf', 'vingt', 'vingt et un', 'vingt-deux', 
         'vingt-trois', 'vingt-quatre', 'vingt-cinq', 'vingt-six', 'vingt-sept', 
         'vingt-huit', 'vingt-neuf', 'trente', 'trente et un']
jours = [x.replace('-', '(?:-| )') for x in jours]
jours_ieme = [re.sub(r'e$', 'i[èe]me', x.replace('-', '(?:-| )')) for x in jours]
jours_ieme = [x.replace('f', 'v') + 'i[èe]me' if 'i[èe]me' not in x else x for x in jours_ieme]
jours_ieme[0] = 'premier'
annees = ['mil huit cent cinquante et un', 'mil huit cent cinquante deux', 
         'mil huit cent cinquante trois', 
         'mil huit cent cinquante quatre', 'mil huit cent cinquante cinq']
annees = [x.replace(' ', '(?:-|\s*|\s*d°\s*)') for x in annees]
mois = ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 
        'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']

# %%
i = np.random.randint(len(actes))

def get_date_registre(acte):
    """
    Objective get the date of the acte
    """
    date_texte = re.split(r'((?:[Pp]ar-devant|(?:est|sont) comparu))', acte)[0]
    date_texte = re.sub(r'(?:{})'.format('|'.join(annees)), 'ANNEE', date_texte.lower())
    
    m = re.search(r'(?:{})\b'.format('|'.join(mois)), date_texte.lower())

    if m:
        j = re.search(r'(?:{})'.format('|'.join(jours_ieme[::-1] + jours[::-1])), 
                         date_texte.lower()[:m.start()])
        m = m.group()
        if j:
            j = j.group()
        else:
            j = None
    else:
        m = None
        j = re.search(r'(?:{})'.format('|'.join(jours_ieme[::-1] + jours[::-1])), 
                         date_texte.lower())
        if j:
            j = j.group()
        else:
            j = None
        
        
    if not m:
        splits = re.split(r'\bmois d[e\']\b', date_texte.lower())
        if len(splits) > 0:
            _m = splits[-1].strip().split(' ')[0]
            for _mois in mois:
                if ratio(_mois, _m) > 0.5:
                    m = _mois
                    
                    
    if not m and j:
        splits = re.split(j, date_texte.lower())
        if len(splits) > 0:
            _m = splits[-1].strip().split(' ')[0]
            for _mois in mois:
                if ratio(_mois, _m) > 0.5:
                    m = _mois
                    
    if not m:
        words = date_texte.lower().split(' ')
        for word in words:
            if word == 'maire':
                continue
            for _mois in mois:
                if ratio(_mois, word) > 0.7:
                    m = _mois
    return m, j

get_date_registre(actes[i])
# Out:
# ('avril', 'huit')

# %%
df.loc[:, 'registre_mois'] = df.loc[:, 'acte_pp'].apply(lambda x: get_date_registre(x)[0])
df.loc[:, 'registre_jour'] = df.loc[:, 'acte_pp'].apply(lambda x: get_date_registre(x)[1])
df.loc[:, ['registre_mois', 'registre_jour']].notnull().mean()*100
# Out:
# registre_mois    97.356851
# registre_jour    98.264783
# dtype: float64

# %%
notnulls = df.drop(labels='commune', axis=1).notnull().groupby(df.commune, sort=False).sum()
notnulls.loc[:, 'registre_mois'] =notnulls.loc[:, ['registre_mois', 'acte']].apply(lambda x: x[0]/x[1] * 100,
                                                                                   axis=1)
notnulls.loc[:, ['registre_mois']].sort_values('registre_mois')
# Out:
#                        registre_mois
# commune
# 19. Prêcheur               93.221871
# 14. Grand Bourg de MG      95.049505
# 17. Moule                  95.079220
# 3. Basse Pointe            95.202791
# 14. Lorrain                95.306535
# 4. Carbet                  95.960740
# 27. Sainte Luce            96.051333
# 12. Gourbeyre              96.748507
# 15. Macouba                97.012987
# 20. Rivière Pilote         97.183847
# 21. Rivière Salée          97.223650
# 24. Saint Joseph           97.288360
# 16. Morne à l'Eau          97.950220
# Trois Rivière             97.975416
# 22. Robert                 98.111380
# Sainte Anne                98.122066
# Saint Louis                98.298677
# 31. Trois Ilets            98.306233
# Vieux Habitants            98.427073
# 1. Abymes                  98.747335
# 23. Saint Esprit           98.792918
# 16. Marigot                98.867925
# 8. Capesterre de MG        98.869347
# Sainte Rose                98.875639
# Pointe à pitre            99.292235
# 1. Ajoupa Bouillon        100.000000

# %%
_communes = notnulls.loc[:, ['registre_mois']].sort_values('registre_mois').index[:3]
for x in df.loc[(df.loc[:, 'registre_mois'].isnull()) &
                (df.loc[:, 'commune'].isin(_communes)), 'acte_pp'].sample(10):
    
    x = re.split(r'((?:[Pp]ar-devant|(?:est|sont) comparu))', x)[0]
    print(x)
    print('---')
    regex = r'(?:{})\b'.format('|'.join(mois))
    match = re.search(regex, x.lower())
        
    if match:
        print(match.group())
    print('------------------')
    print('------------------')
# Out:
# L'an Mil huit cent cinquante Six, le dernier
# ---
# ------------------
# ------------------
# Aujourd'hui trois de relevée mil huit cent cinquante-cin à l'heure de midi,
# ---
# ------------------
# ------------------
# L'an mil huit cent cinquante vingt Commune,
# ---
# ------------------
# ------------------
# Aujourd'hui Juge appléant et du arrêté mil huit cent quatre-vingt-cinq, à heures Desbonnes, par
# ---
# ------------------
# ------------------
# Aujourd'hui quatorze mil huit cent cinquante-cinq à naîcheures du matin,
# ---
# ------------------
# ------------------
# L'an mil huit cent cinquante, cinq et le vingt-cinq trent, domicilié,
# ---
# ------------------
# ------------------
# Aujourd'hui Népublique Française mil huit cent quatre-vingt-seize à heures du nom par
# ---
# ------------------
# ------------------
# Aujourd'hui vingt quatre était mil huit cent quatre vingt treize, à neuf heures du matin, par devant Nous, Virsel Etienne, premier adjoint au Maire, de légué aux fonctions d'officier de l'Etat-Civil de la commune du Grand Bourg,
# ---
# ------------------
# ------------------
# L'an mil huit cent cinquante deux et le eue mère à sept heures donatie
# ---
# ------------------
# ------------------
# Aujourd'hui vingt et un droit mil huit cent cinquante-cinq à une heure de relevée,
# ---
# ------------------
# ------------------

# %%
mois = df.loc[:, 'registre_mois'].values
year = df.loc[:, 'year'].values
cleaned_mois = []
for j, _mois in enumerate(mois):
    if j == 0 or j == len(mois) - 1:
        cleaned_mois.append(_mois)
        continue
    if _mois:
        cleaned_mois.append(_mois)
    else:
        
        l, k = j, j
        while not mois[l]:
            l -= 1
        while not mois[k]:
            k += 1

        if mois[l] == mois[k]:
            cleaned_mois.append(mois[l])
        elif mois[l] == 'décembre' and mois[k] == 'janvier' and (year[l] == year[j] or year[k] == year[j]):
            if year[l] == year[j]:
                cleaned_mois.append(mois[l])
            else:
                cleaned_mois.append(mois[k])
        else:
            cleaned_mois.append(_mois)

df.loc[:, 'registre_mois'] = cleaned_mois
df.loc[:, ['registre_mois', 'registre_jour']].notnull().mean()*100
# Out:
# registre_mois    98.980202
# registre_jour    98.264783
# dtype: float64

# %%
df
# Out:
#                                                     acte  \
# 0                                        Premier juillet
# 1      Aujourd'hui, Samedi Six Janvier mil huit cent ...
# 2      Aujourd'hui, Lundi huit Janvier mil huit cent ...
# 3      Aujourd'hui, Lundi huit Janvier mil huit cent ...
# 4      Aujourd'hui, Samedi treize Janvier mil huit ce...
# ...                                                  ...
# 76873  L'an mil huit cent quatre-vingt-quinze, le hui...
# 76874  L'an mil huit cent quatre vingt-quinze, le neu...
# 76875  L'an mil huit cent quatre vingt-quinze, le onz...
# 76876  L'an mil huit cent quatre vingt quinze, le sei...
# 76877  L'an mil huit cent quatre vingt quinze, le vin...
#
#                         photo          commune  year  \
# 0      FRANOM49_1DPPC0954_225  Vieux Habitants  1855
# 1      FRANOM49_1DPPC0954_225  Vieux Habitants  1855
# 2      FRANOM49_1DPPC0954_225  Vieux Habitants  1855
# 3      FRANOM49_1DPPC0954_226  Vieux Habitants  1855
# 4      FRANOM49_1DPPC0954_226  Vieux Habitants  1855
# ...                       ...              ...   ...
# 76873  FRANOM21_1DPPC1705_078      16. Marigot  1895
# 76874  FRANOM21_1DPPC1705_078      16. Marigot  1895
# 76875  FRANOM21_1DPPC1705_079      16. Marigot  1895
# 76876  FRANOM21_1DPPC1705_079      16. Marigot  1895
# 76877  FRANOM21_1DPPC1705_079      16. Marigot  1895
#
#                                                  acte_pp registre_mois  \
# 0                                        Premier juillet       juillet
# 1      Aujourd'hui, Samedi Six Janvier mil huit cent ...       janvier
# 2      Aujourd'hui, Lundi huit Janvier mil huit cent ...       janvier
# 3      Aujourd'hui, Lundi huit Janvier mil huit cent ...       janvier
# 4      Aujourd'hui, Samedi treize Janvier mil huit ce...       janvier
# ...                                                  ...           ...
# 76873  L'an mil huit cent quatre-vingt-quinze, le hui...      décembre
# 76874  L'an mil huit cent quatre vingt-quinze, le neu...      décembre
# 76875  L'an mil huit cent quatre vingt-quinze, le onz...      décembre
# 76876  L'an mil huit cent quatre vingt quinze, le sei...      décembre
# 76877  L'an mil huit cent quatre vingt quinze, le vin...      décembre
#
#       registre_jour
# 0           premier
# 1               six
# 2                un
# 3                un
# 4            treize
# ...             ...
# 76873          huit
# 76874          huit
# 76875          huit
# 76876          huit
# 76877          huit
#
# [76878 rows x 7 columns]

# %% [markdown]
# **Type Évènement**

# %%
i = np.random.randint(len(actes))

def get_act_type(acte):
        
    acte = acte.lower()
    
    if re.search('enfant san(?:s|) vie', acte):
        return 'naissance/mort'

    deces = ['d[eé]c[eé]d[ée](?:e|)', 'décès', 'défunt', 'nous en somme(?:s|) assuré',
             '(?:somme(?:s|)|être) assuré', 'nous nous(.*?)assuré']
    naissance = ['te de naissance', 'présenté', 'a(?: été|) présent[eé]', 
                 'nous présente', 'le(?:s|) prénom(?:s|)', "est né d'elle", 'est accouché',
                 'est sort[ie] du sein','accouch','est né',
                "l'enfant a été"
                ]
    mariage = ['mariage', 'c[eé]l[eé]bration', '[eé]poux','unis par les liens', 
               'mari et (pour)* femme','consentant']
    reconnaissance = ['reconna[iî]tre', 'reconnaît','reconnait [pm]ère', 
                      'reconnaissance', 'reconnaissant', 
                       "registres de (?:naissance|l'[eé]tat civil)",
                      'se reconnait être', 'reconnait pour']

    n_deces = len(re.findall(r'(?:{})'.format('|'.join(deces)), acte))
    n_naissance = len(re.findall(r'(?:{})'.format('|'.join(naissance)), acte))
    n_mariage = len(re.findall(r'(?:{})'.format('|'.join(mariage)), acte))

    if n_deces > n_naissance and n_deces > n_mariage:
        return 'décès'
    
    if n_mariage > n_naissance and n_deces < n_mariage:
        return 'mariage'
    
    if n_deces < n_naissance and n_naissance > n_mariage:
        if 'registre de naissance' in acte:
            return 'reconnaissance'
        else:
            return 'naissance'
    
    if n_deces == n_naissance and n_naissance > n_mariage:
        return 'naissance/mort'
    
    if n_deces == n_naissance and n_naissance == n_mariage and n_mariage == 0:
        n_reconnaissance = len(re.findall(r'(?:{})'.format('|'.join(reconnaissance)), acte))
        if n_reconnaissance > 0:
            return 'reconnaissance'
        
    
    return None
acte = df.sample(1).loc[:, 'acte_pp'].values[0]
#acte = "L'an mil huit cent cinquante trois, le douzième jour du mois de Janvier, dix heures du matin, Par-devant nous Amelée Bertrand (Roussel Bonneterre adjoint, remplissant les fonctions de Maire et d'officier de l'état civil de la commune du sieur fort Saint Louis Marie Galante Est comparu le sieur Exideuil Léard agé de trente un ans, cultivateur domicilié en la commune du cin fort Saint Louis, Lequel nous a déclaré que le dix de a mois se onze heures du matin, il est né un enfant du Sexe masculin qu' nous présente et auquel il donne le prénom de Herrot, se reconnai sant pour être le père de cet enfant et l'avoir eu de la demoiselle Eliette Broette agée de trente ans, cultivatrice domiciliée en la susdite commune sur habitation Létang Long. Lequel enfant est né au dit lieu. Les dites déclaration et présentation faites en présence des sieurs Rosmin Latrimail agé de trente sept ans et Saturnin alsalon agé de vingt un ans, tous deux cultivateurs domiciliés en la sus dite commune. Et après lecture faite nous avons seul signé le présent acte de naissance, le père et les témoins ayant déclaré ne savoir écrix ni signer de ce requis Amédée R. Bonneterre"
type_acte = get_act_type(acte)
type_acte
# Out:
# 'naissance/mort'

# %%
df.loc[:, 'registre_type'] = df.loc[:, 'acte_pp'].apply(lambda x: get_act_type(x))
df.loc[:, ['registre_type', 'registre_mois', 'registre_jour']].notnull().mean()*100
# Out:
# registre_type    99.088166
# registre_mois    98.980202
# registre_jour    98.264783
# dtype: float64

# %%
df.registre_type.value_counts()
# Out:
# naissance         35966
# décès             29746
# mariage            7303
# naissance/mort     1969
# reconnaissance     1193
# Name: registre_type, dtype: int64

# %%
notnulls = df.drop(labels='commune', axis=1).notnull().groupby(df.commune, sort=False).sum()
notnulls.loc[:, 'registre_type'] =notnulls.loc[:, ['registre_type', 'acte']].apply(lambda x: x[0]/x[1] * 100,
                                                                                   axis=1)
notnulls.loc[:, ['registre_type']]
# Out:
#                        registre_type
# commune
# Vieux Habitants            99.332698
# 8. Capesterre de MG        99.539363
# 23. Saint Esprit           99.195279
# 3. Basse Pointe            99.258613
# Saint Louis                99.149338
# 1. Abymes                  99.360341
# 14. Lorrain                99.326297
# 16. Morne à l'Eau          99.267936
# 21. Rivière Salée          98.560411
# 19. Prêcheur               98.373249
# 20. Rivière Pilote         98.538789
# 31. Trois Ilets            97.899729
# Sainte Rose                99.386712
# Sainte Anne                99.295775
# 14. Grand Bourg de MG      99.579208
# 1. Ajoupa Bouillon         98.717949
# Trois Rivière             99.493854
# 17. Moule                  98.689823
# 27. Sainte Luce            98.815400
# 4. Carbet                  99.358248
# 12. Gourbeyre              98.871931
# 24. Saint Joseph           99.338624
# Pointe à pitre            98.881937
# 15. Macouba                98.896104
# 22. Robert                 99.346247
# 16. Marigot                99.056604

# %%
_communes = ['17. Moule', '31. Trois Ilets', '23. Saint Esprit']
for x in df.loc[(df.loc[:, 'registre_type'].isnull()) &
                (df.loc[:, 'commune'].isin(_communes)), 'acte_pp'].sample(10):
    
    print(x)
    deces = ['d[eé]c[eé]d[ée](?:e|)', 'décès', 'défunt', 'nous en somme(?:s|) assuré', 'être assuré']
    naissance = ['acte de naissance', 'présenté', 'a(?: été|) présent[eé]', 
                 'nous présente', 'le(?:s|) prénom(?:s|)', "est né d'elle", 'est accouché',
                 'est sort[ie] du sein','accouch','est né']
    mariage = ['mariage', 'c[eé]l[eé]bration', '[eé]poux','unis par les liens', 
               'mari et (pour)* femme','consentant']
    reconnaissance = ['reconna[iî]tre', 'reconnaît','reconnait [pm]ère', 
                      'reconnaissance', 'reconnaissant']

    n_deces = len(re.findall(r'(?:{})'.format('|'.join(deces)), x))
    n_naissance = len(re.findall(r'(?:{})'.format('|'.join(naissance)), x))
    n_mariage = len(re.findall(r'(?:{})'.format('|'.join(mariage)), x))
        
    print(n_deces, n_naissance, n_mariage)
    print('------------------')
    print('------------------')
# Out:
# L'an mil huit cent cinquante Six et le vingt quatre décembre, à dix heures du matin, par devant nous Joseph Antoine Ifis Desbonne, maire, adjoint de l'état civil de la Commune de Moule, île Guadeloupe est comparu le sieur Louis Pascal, âgé de vingt cinq ans, commis, domicilié en cette Commune, et auquel nous a présent un enfant de sexe masculin, né le quatorze du ce mois, à midi, en cette vissi, Granderne, 4°37, de son légitime Mariageavec la dame Jeannaine présette, âgée de trente deux ans, propriétaire, et auquel il a déclaré nuloir donner les prénoms de Lucien Alexis Victor Camille, lesdites déclaration et présentation faites en présence des sieurs frénoms Inget agé de quarante Six ans et Paul Armand, âgé de vingt deux ans, tous deux Sans profession, demeurant en cette Commune, qui ont signé avec nous et le comparant le présent acte, après lecture Marget Teneau N°44 J. Hte Adrien N°44
# 0 1 0
# ------------------
# ------------------
# L'an mil huit cent cinquante cinq et le mardi seize du mois d'octobre à onze heures du matin, par devant nous Auguste nicole, adjoint au maire de la commune des Trois Ilets, auquel le dit maire a délégué par arrêté du neuf ans domiciliés les fonctions d'officier de l'état civil de la dite commune, arrondissement de Fort de France est comparu le Sieur Gervais morland, agé de trente huit ans, habitant, et Montout fils agé de vingt deux ans, sans profession, tous de domiciliés en cette sus dite commune, âgé de quels ans, ont déclaré que l'enfant Edvily, âgé de cinq ans, sans profession, domiciliés auSsé que, agée de quarante quatre ans, cultivatrice, domiciliée en cette six sur le propriété de Gérémie Morland, située en cette commune ainsi que nous nous en sommes signé né; et avons signé le présent acte après leur en avons fait lecture avec Montout fils, Gérémie morland n'ayant pu ou su le signer. De ce enquis The Montout A Auguste nial
# 0 0 0
# ------------------
# ------------------
# L'an mil huit cent cinquante trois et le vingt cinq juin, à neuf heures du matin, Par-devant nous, Joseph Antoine Disbonne, premier adjoint au maire de la Commune du Moule auquel le dit maire a délégué, par arrêté du dix janvier mil huit cent cinquante deux, les fonctions d'officier de l'Etat civil, est Comparu le Sieur IsaacHanatin, âgé de cinquante trois ans, cultiva teur, domicilié en cette Commune. lequel nous a présenté un enfant du sexe masculin né le quinze du mois, à onze heures du matin, sur l'habitation Marchand Située en cette commune, section de Clagouy de son légitime Mariageavec la dame Pauline Phil âgée de trente sept ans, Cultivatrice, et auquel d'adéclaré ne savoir donner le premier Le Isaac, les dites déclaration et présentation faites en présence des sieurs Saint Pierre Calazan, âgé de cinquante neuf ans, et Charles Crantol, âgé de quarante sept ans, tous les deux cultivateurs, domi en cette Commune. Et nous avons signé seul le présent acte, le comparant et les témoins ayant déclaré ne savoir le faire, de ce interpellés, après lecture. J. Desbonne
# 0 1 0
# ------------------
# ------------------
# L'an mil huit cent cinquante six et le dix Avril, de dix heures du matin, par devant nous Joseph Antoine Ifis Desbonne, maire officier de l'Etat civil de la Commune du Moule, Ile Guadeloupe Sont comparus les sieurs Daniel Thérion, âgé de trente quatre ans, et Charles françois Oribon, âgé de trente six ans, tous deux cultivateurs domiciliés en cette Commune, lesquels nous ont présenté un enfant leur vie, de sexe féminin, né, hier à huit heures du soir sur l'habitation lesménées située en cette Commune, Section de les maire du Monl Ouest, du légitime Mariagedu dit al avril Thérin, et de la dame Simonne Antoniste Thixre, âgée de trente quatre ans, cultivatrice; et nous avons signé seul le présent acte, les Comparante ayant déclaré ne Savoir le faire, de ce interpellés, après lecture de Ste Anne
# 0 1 0
# ------------------
# ------------------
# L'an mil huit cent cinquante six et le trente et un du mois de Mai à midi. Par Devant nous Charles Edouard Signol maire et officier de l'etat civil de la commune de Saint-après chef lieu de canton, arrondissement de fort de france martinique, est comparice en notre maison commune la Demoiselle Antoinette Gabrielty, âgée de trente trois ans, cultivatrice domiciliée dans la commune de Saint-Espres laquelle nous a déclaré qu'elle se recon nait pour être la mère d'un enfant du sexe masculin dont le nom suit Florimond né le dix sept Octobre mil huit cent trente neuf dans la commune susdite, y domicilié, et inscrit aux registre du actes d'in individualité sous le numéro Cinq ans quarante sept. Les dites déclarations faites en présence des sieurs Nelson Maria âgé de trente trois ans domestique, et Louis Coco âgé de trente et un ans, garçon boulanger, tous deux domiciliés dans la commune de Sainte Après Et avons signé le présent acte de recon naissance, la comparante et les témoins ayant déclaré ne savoir signer de ce Enquis lecture faite : St Juinot
# 0 0 0
# ------------------
# ------------------
# L'an mil nous leur cinquante cinq, à le vingt du mois de septembre, cinq heures de relevée. Par devant nous Charles Edouard Signal, Maire et officier de l'Etat Civil de la Commune de Saint Espin, chef lieu de Vanton, arrondissement de fort de france Martinique, sous com parus en notre maison Commune, les nous Aujour Arnolin dit Féline, âgé de vingt sept ans, cultivateur, et nelson extra, âgé de trente trois ans, domestique, tous deux domicilié dans la Commune de Saint Eyris Lesquels nous ont présenté un enfants ray vie du Sexe masculin, et nous ont déclaré que les père et mère de cet enfant sont le sieur nelson Magontis, âgé de trente deux au, et la dame Lausine Mathérot, sous époux, âgée de trente huit ans, tous deux cultivateurs domiciliés dans la Commune de Saint-Esprit; et qui l'estre treize du présent mois de septembre que l'enfant est torte du lieu de sa mère. Et avons signé le présent acte, les comparants ayant déclaré ne savoir signer de cinquis, lecture faite./.
# 0 1 1
# ------------------
# ------------------
# L'an mil huit cent cinquante trois et le vingt trois juinat à deux heures et demie de relevé, par devant nous, Joseph antoi Yves Desbonne, premier adjoint au maire de la Commune Moule, auquel le dit maire a délégué, par arrêté du dix maison mil huit cent cinquante deux, les fonctions d'officier de l'Etat Civil, sont comparus, en notre maison Commune, le Sieur andré Abindé, âgé de quarante deux ans, cultivateur né en afrique, demeurant au Moule sur l'habitation Blanotet, Section de Matimer, fils de père et de mère inconnus et la demoiselle Isménie Deslandes, âgée de vingt
# 0 0 0
# ------------------
# ------------------
# L'an mil huit cent cinquante six, et le sept avril, à huit heures du matin, par devant nous, Joseph Antoine Elis Desbonne maire par intérine, officier de l'Etat civil de la Commune du Moule île Guadeloupe, sont comparus les Sieurs Jacques Alexandre Vantier, âgé de quarante trois ans, et Jean Baptiste Monsaret, âgé de trente trois ans, le premier commerçant, le deuxième sans profession, tous deux domiciliés en cette Commune, Lesquels nous ont déclaré que, hier à dix heures du soir, le Sieur Charles Auguste Cassy, âgé de cinquante deux, sans profession, né à la Pointe aprètre, demeurant au Moule, neuf déclaré Victoire Cléonette Sargustin, fils légitime des feue Louis Marie Joseph Alexandre Terley et dame Marie Anne Rose Arfumeau, de leur vivant propriétaires avec Moule, est décéd, en cette ville, rue Grumile, nous cette déclaration et après insistre Allouardudit derés, nous avons dressé le présent acte, que les comparants ont signé avec nous, après lecture. Ile Nomses Sautier Gt Sylvin
# 0 0 0
# ------------------
# ------------------
# L'an mil huit cent cinquante trois et le vingt six mars à huit heures du matin, Par-devant nous, Joseph Antoine Isis Desbonne, premier adjoint au maire de la Commune du Moule, auquel le dit maire a délégué, par arrêté du dix janvier mil huit cent cinquante deux les fonctions d'officier de l'Etat civil, est comparu le Sieur Lucien Dumentier âgé de trente cinq ans, orfère, domicilié en cette Commune. Lequel nous a présenté un enfant du sexe féminin, né le dix neuf, de ce mois à onze heures du soir, en cette ville, rue de la loire n°14 de feu légitime Mariageavec la dame Profella Brun, âgée de dix neuf ans, sans profession, et auquel il a déclaré vouloir donner les premier de Marie Alaiza. Les dites déclaration et présentation faites en présence des Sieurs Charlemagne Zoël Agnès, âgé de trente quatre ans, huissier, et Auguste Péron, âgée de vingt huit ans, tailleur, tous les deux domiciliés en cette Commune, qu'ont signé avec nous et le comparant le présent acte après lecture. Nte Pierre Lamentin Ef. Lélègnet N°
# 0 1 0
# ------------------
# ------------------
#  Aimée juillet P de l'arrêtime du trésence A. Tite 5°
# 0 0 0
# ------------------
# ------------------

# %%
naissances = df.loc[df.loc[:, 'registre_type'] == 'naissance', :].copy()
deces = df.loc[df.loc[:, 'registre_type'] == 'décès', :].copy()
mariages = df.loc[df.loc[:, 'registre_type'] == 'mariage', :].copy()
reconnaissances = df.loc[df.loc[:, 'registre_type'] == 'reconnaissance', :].copy()
mortsnes = df.loc[df.loc[:, 'registre_type'] == 'naissance/mort', :].copy()

# %%
## Pour regarder des exemples: changer naissance par deces, mariages, reconnaissance, mortsnes

for x in naissances.sample(10).loc[:, 'acte_pp'].values:
    print(x)
    print('---')
# Out:
# L'an mil huit cent cinquante deux et le samedi premier jour du mois de Mai, à quatre heures après midi. Par-devant nous Jacques adolphe de sagrange chancel, Maire de la commune du Robert canton de la Trinité, arrondissement de Saint Pierre, île Martinique, officier de l'Etat civil de la dite commune. Est comparu les demoiselle Marie Ange Lauhon, âgée de trente quatre ans, cultivatrice, domiciliée en cette Commune laquelle nous a déclaré que le premier du mois d'avril dernier, à quatre heures du matin, elle est accouchée dans sa maison sur l'habitation dite Sainte Savanne, sise en cette commune, d'un enfant du sexe marcelin qu'elle nous présente et auquel elle donne le prénom de Eugène, se reconnaissant pour être le mère de ch enfant. Les dites déclaration et présentation faites en présence des sieurs, adjoint Lauhon, âgé de quarante deux ans, cultivateur et Edouard Vallier, âgé de quarante sept ans, concierge de la mairie, tous deux domiciliés en cette Commune et nous avons seul signé le présent acte de naissance, le mère et les témoins ayant déclaré ne savoir de ce requis né au lecture leur en a été faite Sagrange Chancel
# ---
# Aujourd'hui neuf Octobre mil huit cent quatre-vingt-seize à neuf heures du matin par-devant nous Etienne Sainte Rose Bernard Chevalier du mérite agricole, Maire et Officier de l'état civil de la commune de trois Rivières, est comparu le sieur Pierre Mahy-agé de vingt quatre ans, charpentier, domicilié en cette commune, lequel nous a présenté un enfant du sexe masculin, né le premier Octobre courant, à trois heures du matin, de lui déclarant, et de la dame Elisabeth Camme, son épouse, agée de vingt neuf ans, sans profession, dans le domicile des époux, sis Section du Huit trou aux-chiers jauquel enfant il a déclaré vouloir donner le prénom de Remi; lesdites déclaration et présentation faites en présence des sieurs Prudent Jean-Charles, âgé de trente huit ans, Gardi champêtre, et Hyacinthe Romain, agé de trente-six ans, gardien de la maison de police, tous deux domiciliés en cette commune. Et le déclarant et les témoins ont signé avec nous le présent acte de naissance après qui leur en a été donné lecture Mahy Pierre S. Jean Charles B N° A Vernais
# ---
# L'an mil huit cent cinquante trois, et tétrois domiciliés Décembre, à neuf heures du matin, devant mil Jean François Remy E Sude, agé de trente trois ans, devant, officier de l'état civil de la commune du Lorave, Grand'anSs et Mangot, arrondissement de Saint-Pierre, le Martrand que, et comparu le Sieur Nicolas Placide Gabriel, âgé de vingt ans, cultivateur, domicilié à la Grand'Anfer, sur l'habitation de dame Anne Louise Duval Auguste, lequel nous a déclaré que le quatorze du mois de Novembre dernier, à huit heures du matin, et l'Etat civil de la demeure, sur l'habitation seite délégué un enfant du sexe féminin qu'il nous présente, et auquel il déclare donner les prénoms de Marie Placide, quel enfant et ont de la dame Rose Calorel, lesquels, âgée de déclarant ans, couturière, domiciliée au sexe les dites déclarations et présentation faites en présence de s Saint Martial Cabimel, âgé de quarante six ans cultivateur, domicilié à la Grand'Anse, sur l'habitation de la dite dame heures Louis Duval Eugué, Grand père de l'enfant et Fabien Chébrier, agé de quarante cinq ans, agist cultivateur, domicilié au maire lieu, témoins choisis par le comparant; et avons signé seul le présent acte de naiSsance, le père et le témoins ayant déclaré ne savoir signer, de ce parents requis après qu'il leur en a été donné lecture if
# ---
# Aujourd'hui, lundi vingt neuf du mois Octobre mil huit cent quatre vingt-quatorze, à huit heures du matin par devant nous Michel d'anctus Maire et Officier de l'Etat civil de la commune de Saint Marie Galante, est comparu le sieur Fargeau Baitier âgé de cinquante huit et un ans, charpentier domi lié en cette commune, section des hauts, hameau Mate lequel nous a présenté une enfant du sexe féminin Mingt, et un du dit mois, à dix heures du soir, de lui décl sont en sa demeure sise au dit au lieu, et de la dame Urie Elisabeth ans, cultivatrice, domiciliée en cette dite Commune aux mêmes section et hameau, et auquel enfant if a déclaré, vouloir donner les prénoms de Calixte Aucharis. Les dites déclaration et présentation faites en présence des sieurs Urie Moïse, âgé de trente six ans, Luzio Loussing Victor, âgé de cinquante-cinq ans, habi propriétaires, domiciliés en cette sus-dite Commune section des haures de hauts hameau Lahaut; Etale second témoin âgée avec nous le présent Acte, naissance, après de fil leur en a été donné lecture. Pé déclarant et le premier témoins ne le sachant de ce requis./. quatre mots rayés nuls V.Luzie Albert N° fils
# ---
# L'an mil huit cent quatre vingt quatorze et le treize Mars à quatre heures et demie du soir, à la mairie, par devant nous Le sous Prospeet Emile, adjoint au maire et officier de l'Etat civil de la commune de Sainte Luce, canton du Diamant, arrondissement du Fort de-France, île Martinique, a comparu la demoiselle Guillon (Marie Denise, âgée de vingt six ans, couturière domiciliée au Gros-Morne, demeurant présentement à Sainte Luce sur l'habitation Anse Maloupe laquelle nous a déclaré que le dit neuf février dernier, à onze heures du matin dans la maison de la dite habitation, il est né d'elle déclarante une enfant du sexe féminin, qu'elle 18 nous a présentée et à laquelle elle a déclaré vouloir donner le prénom de Jeanne. Les dites déclaration et présentation faites en présence des sieurs Emmanuel Perrier, secrétaire de mairie, âgé de trente deux ans, et Dancaldi Isidore, économe d'habitation âgé de trente et un ans, tous deux domiciliés en cette commune, non parents de l'enfant. Dont acte que nous avons signé, avec la comparante et les témoins, lecture faite./. moins, lecture faite. Srès Etat Denise Grillon
# ---
# L'an mil huit cent cinquante trois, et le vingt du mois de septembre à midi, Par-devant nous Ophrem doulogne membre de la commassion municipale le Septième dans l'ordre du tailleur, remplissant par délégation du maire en date du seize de ce mois, les fonctions d'officier de l'Etat civil de la commune de la capesterre Marie Galante, est comparus le Sieur Cinéry Varo âgé de trente trois ans cultivateur domicilié en cette commune Section des Baliziers hameau Nesmond N°13, lequel nous a déclaré que le douze de ce mois à trois heures de relevée, il est né un enfant du sexe féminin qu'il nous présente et auquel il a déclaré donner le prénom domelie, se reconnaissant pour être le père de cet enfant et l'avoir eu de la demoiselle Coralie Létic âgée de trente trois ans, cultivatrice domiciliée en la dite commune Section des Balizien hameau Nesmond N°13, lequel enfant est né en la demeure de sa mère Sise au dit hameau Second Les dites déclaration et présentation faites en présence des Sieurs Louis Marie Rigaudin âgé de vingt et un ans commis de Négociant, et Edouard Gareau Demaray âgé de trente huit ans, sans profession, domiciliés tous deux au bourg de cette commune Section des Pèsès rue de la marine N°21 et 6; et ont les témoins signé avec nous le présent acte de naissance, l'éclarant a répondu de ce requis ne savoir écrire ni signer après lecture donnée Em Bouloyne Rivandine Démaray
# ---
# L'an mil huit cent quatre vingt seize et le cinq février, à deux heures de relevée, Par-devant nous, Tiburce Hippolyte, premier adjoint au maire de la commune de la Rivière-Salée, canton du Saint Cyrrit, arron dissement de Fort-de-France, île Martinique, remplissant les fonctions d'oflieu de l'état civil à la place du Maire en centé. A comparu, la demoiselle le Parthé Marie Athénais surnommée Médélice, âgée de trente et un ans, couturière domiciliée en cette commune, laquelle nous a déclaré, que le vingt huit décembre dernier, à sept heures du soir, dans sa demeure, sise au quartier démarinières, en cette commune, elle est accouchée d'une enfant du sexe féminin qu'elle nous présent, île reconnaissant pour en être la mère, et à laquelle elle déclare donner le prénom de Elisabeth Les dites déclaration et présentation faites en présence des Sieurs Beauplais Baillard, âgé de Soixante huit ans, ferétaire de mairie et Pierre Jules, âgé de vingt huit ans, habitant, tous deux domiciliés à la Rivière Salée, témoins choisis par la comparante. Et avons signé le présent acte avec les témoins, la comparante ayant déclaré ne le savoir après lecture J. Pierront J.Charles Daissant F. H. Tiburce
# ---
# Aujourd'hui treize Octobre mil huit cent quatrevingt douze, à trois heures du soir, par devant Nous, Pasil (Etienne) premier adjoint au Maire, délégué aux fonctions d'officier de l'Etat Civil de la commune du Grand Bourg, est comparu le sieur Ha bazac (Pierre), âgé de quarante-cinq ans, charpentier, domicilié en cette commune, lequel nous a présenté un enfant du sexe masculin, né le quatre de ce mois, à onze heures du matin, en la demeure maternelle ci-après désignée, de la demoiselle Antenor (Pauline), âgée de trente huit ans, ménagère, domiciliée et demeurant en cette commune, rue projetée, auquel enfant il a déclaré vouloir donner les prénoms de François Léon, les dites déclaration et présentation faites en présence des sieurs Girard Giraud Bellevue, âgé de (nois Galante) trente-neuf ans, ébéniste, et Alcindor Germain, âgé de cinquante huit ans, brigadier de Folice, tous deux Vrimbre domiciliés en cette dite Commune, et ont le déclarant et les témoins, signé avec Nous le présent Acte de Naissance après qu'il leur en a été donné lecture. B. Girard B. Girard Tersil Alcindor S K Mabazse
# ---
# Aujourd'hui quatre novembre mil huit cent quatre-vingt-seize à deux heures de relevée par-devant nous Versil Etienne, premier adjoint au Maire, délégué aux fonctions d'Officier de l'état civil de la commune du Grand Moulo, est comparu l'un dieu Ramaye François, âgé de vingt sept ans, cultivateur, numéro d'21 domicilié et demeurant en cette commune, habitation grand'Anse lequel nous a présenté un enfant du sexe féminin, né le vingt sept Octobre dernier, à cinq heures du matin, en sa demeure sus désignée, de lui déclarant, et de l'indienne Mangalom Caye dite Marie, âgée de vingt neuf ans, cultivatrice, numéro 12466, domiciliée et demeurant au même lieu, auquel enfant if a déclaré vouloir donner le prénom de Marceline, se reconnaissant en être le père, les dites déclaration et présentation faites en présence des sieurs Bany (Louis), âgé de trente trois ans, et Hachy (Luc) âgé de trente quatre ans, tous deux cultivateurs, domiciliés et le premier témoin seul a signé avec nous le présent acte de naissance après qu'il leur en a été donné lecture le déclarant ni le second témoin N° Rany Louis E Téry N°
# ---
# Aujourd'hui Samedi dix Novembre mil huit cent quatre-vingt-quatorze à neuf heures et demie du matin par-devant nous Terrade Jean-Marie Maire et Officier de l'état civil de la commune de Sainte Rose Guadeloupe, est comparu la demoiselle Pougeol Clémence, âgée de vingt cinq ans, cultivatrice, domiciliée en cette commune laquelle nous a présenté un enfant du sexe masculin, dont elle se re connait la mère, né le deux du courant, à cinq heuros du matin, dans la case qu'elle occupe sise au hameau Cacao, section Grande Rivière, et au quel enfant, elle a déclaré vouloir donner le prénom de Cliacin Théodore lesdites déclaration et présentation faites en présence des sieurs Sopha Alexis, âgé de cinquante-trois ans, cultivateur, Crazan Jean-Baptiste, âgé de cinquante trois ans, charpentier, tous deux propriétaires domiciliés en cette susdite, commune et les mère et témoins n'ont su signé avec nous le présent acte de naissance après qu'il leur en a été donné lecture nous l'avons seul fait N°5 19 2109
# ---

# %%
naissances.to_csv(join(PATH_REPO, 'data', '20230817_transcriptions', 'naissancesRaw.csv'), index=False)
deces.to_csv(join(PATH_REPO, 'data', '20230817_transcriptions', 'decesRaw.csv'), index=False)
mariages.to_csv(join(PATH_REPO, 'data', '20230817_transcriptions', 'mariagesRaw.csv'), index=False)
reconnaissances.to_csv(join(PATH_REPO, 'data', '20230817_transcriptions', 'reconaissancesRaw.csv'), index=False)
mortsnes.to_csv(join(PATH_REPO, 'data', '20230817_transcriptions', 'mortsNesRaw.csv'), index=False)
